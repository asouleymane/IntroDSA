# %% [markdown]
# # Module One: Introduction to the Program and Data Science
#
# ## Notebook Shortcuts
#
# ### Labs
# - [Intro to Data Science with Python](labs/intro_data_science_python.ipynb)
# - [Intro to Data Science with R](labs/intro_data_science_r.ipynb)
#
#
# ### Practice Examples
# - [Practice Data Science with Python](practices/data_science_practice_python.ipynb)
# - [Practice Data Science with R](practices/data_science_practice_r.ipynb)
#
#
# ### Exercises
# - [Intro to Data Science with Python Exercises](exercises/intro_data_science_exercise_python.ipynb)
# - [Intro to Data Science with R Exercises](exercises/intro_data_science_exercise_r.ipynb)
#
#
# ## Topics covered
# - Intro to Mizzou DSA
# - Intro to Data Science as a discipline
# - Intro to Python and R for data science
# - Areas of Concentration and their roles in Data Science
# - The rise of data products
# - Team approaches and roles
# - Systematic method for data science projects
#
# ## Readings
# The following are three examples of how data science is being used/improving to solve different types of problems.
#
# - [Microsoft Finds Cancer Clues in Search Queries](http://www.nytimes.com/2016/06/08/technology/online-searches-can-identify-cancer-victims-study-finds.html?utm_campaign=Data%2BElixir&utm_medium=email&utm_source=Data_Elixir_83&_r=0)- *The New York Times*
# - [AlphaGo: Mastering the ancient game of Go with Machine Learning](https://research.googleblog.com/2016/01/alphago-mastering-ancient-game-of-go.html?utm_campaign=Data%2BElixir&utm_medium=email&utm_source=Data_Elixir_70)- *Google Research Blog*
# - [Is Uber Making NYC Rush-Hour Traffic Worse?](http://fivethirtyeight.com/features/is-uber-making-nyc-rush-hour-traffic-worse/)- *FiveThirtyEight*
#
#
# ## Video topics
#   - **Concept Video**: An Introduction to Data Science
#     - What is Data Science
#     - What Data Science is NOT
#     - The Data Science Life Cycle
#     - The rise of data products
#
#
#   - **Concept Video**: Welcome to Mizzou DSA
#     - General introduction to the program
#     - Areas of Concentration with a brief description of each
#     - Course Structure
#       - 8 week course structure
#       - Types of activities
#       - Weekly module format
#     - Team approach
#
#
#
#
#
# ## Data Sets
# Path: `~/datasets/`
#
# Dataset Name    | File
# ----------------|------------
# Baby Names      | `baby-names/NationalNames1.csv`
# Baby Names 2    | `baby-names/NationalNames2.csv`
# Congress Terms  | `congress-terms.csv`
#
#
# ## Suggested Schedule
#
# ### Monday
# - **Concept Video**: An Introduction to Data Science
# - **Concept Video**: Welcome to Mizzou DSA
# - **Lab Notebook**: Intro to Data Science with Python
# - **Lab Notebook**: Intro to Data Science with R
#
#
# ### Tuesday
# - **Practice Notebook**: Practice Data Science with Python
# - **Practice Notebook**: Practice Data Science with R
#
#
# ### Wednesday
# - Discussion
#
# ### Thursday
# - Discussion Responses
#
# ### Friday/Saturday/Sunday
# - **Exercise**: Intro to Data Science with Python Exercises
# - **Exercise**: Intro to Data Science with R Exercises
